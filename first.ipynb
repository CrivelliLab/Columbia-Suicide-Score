# %%
# import re 
# import csv
# newfile= open('NOTEEVENTS.csv').read().split('\n\n')
# new_file= open('NOTEEVENTS.csv')
# #test for find first N LINES
# N=100
# head = [next(new_file).strip() for x in range(N)]
# print(head)

# test for case insentitive
# actualPattern = re.compile(r"\brow_id\b",re.IGNORECASE) 
# suicidesPattern = re.compile(r"\bsubject_id\b",re.IGNORECASE) 
# actualPattern = re.compile(r"\bROW_ID\b",re.IGNORECASE) 
# suicidesPattern = re.compile(r"\bSUBJECT_ID\b",re.IGNORECASE)

# %%
# actualPattern = re.compile(r"\bactual\b",re.IGNORECASE) 
# suicidesPattern = re.compile(r"\bsuicide\b",re.IGNORECASE) 
# for pg in newfile:
#     pfls = []
#     pg= pg.replace("\n", ' ')
#     if actualPattern.search(pg) and suicidesPattern.search(pg):
#         print('SHIRLEYWANG',pg)

# %%
import os
import re
notes = []
folder= "./notes"
for file in os.listdir(folder):    
    print(file)
# Out:
# 17399_143985.txt
# 6201_112315.txt
# 31851_142689.txt
# 9736_130626.txt
# 11795_113024.txt
# 17282_134677.txt
# 6347_186855.txt
# 87053_127164.txt
# 20245_152770.txt
# 21804_115509.txt
# 46596_168253.txt
# 25992_195084.txt
# 5678_168080.txt
# 21280_118318.txt
# 69528_144133.txt
# 54084_183744.txt
# 14460_163907.txt
# 22303_136547.txt
# 46845_173151.txt
# 69776_133201.txt
# 80511_105135.txt
# 12954_127176.txt
# 48835_153083.txt
# 47906_128544.txt
# 184_137526.txt
# 64798_160505.txt
# 70083_105864.txt
# 87980_134143.txt
# 27872_183384.txt
# 74918_191729.txt
# 8480_174725.txt
# 88764_184080.txt
# 59403_132017.txt
# 14032_160936.txt
# 8981_153214.txt
# 46425_147345.txt
# 5874_186589.txt
# 9686_132328.txt
# 40789_114087.txt
# 908_134650.txt
# 21577_101373.txt
# 18060_129093.txt
# 66326_192701.txt
# 93422_116219.txt
# 18250_183165.txt
# 27194_142739.txt
# 14393_147561.txt
# 27225_129576.txt
# 11049_145016.txt
# 20581_111832.txt
# 13212_185686.txt
# 29862_159196.txt
# 3866_162324.txt
# ...

# %%
for file in os.listdir(folder):
    filepath = os.path.join(folder, file)
    f = open(filepath, 'r')
    newfile= f.read().split('\n')
    #print(newfile)
    actualPattern = re.compile(r"\bactual\b",re.IGNORECASE) 
    suicidesPattern = re.compile(r"\bsuicide\b",re.IGNORECASE) 
    for pg in newfile:
        #pfls = []
        #pg= pg.replace("\n", ' ')
        if actualPattern.search(pg) and suicidesPattern.search(pg):
            print(pg)
            break
    break
